# %%
# !pip install Levenshtein gensim metaspace2020

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sn

from metaspace import SMInstance
import metaspace

from CleaningMetadata import *

import os
import pickle
import random
import pandas as pd

# %% [markdown]
# Get the list of data set IDs.

# %%
tbl_path = os.path.abspath("/scratch/trose/pruned_annotations_dict_300922.pickle")

tbl_list = pickle.load(open(tbl_path, 'rb')) 

fdr_dict = {ds_id: tbl_list[ds_id].fdr.value_counts() for ds_id in tbl_list.keys()}

id_list = list(tbl_list.keys())

# %%
id_list = list(tbl_list.keys())
len(id_list)
# Out:
# 6844

# %%
sm = SMInstance()

# %%
#all_datasets = sm.datasets(status='FINISHED') 
datasets_tim1 = sm.datasets(idMask=id_list[:len(id_list)//2]) # Two Shot query as one is too large
datasets_tim2 = sm.datasets(idMask=id_list[len(id_list)//2:])

# %%
datasets_tim = datasets_tim1 + datasets_tim2

# %%
ds = datasets_tim[50]
#ds.metadata
ds.metadata
# Out:
# {'Data_Type': 'Imaging MS',
#  'Sample_Information': {'Condition': 'Wildtype',
#   'Organism': 'poplar',
#   'Organism_Part': 'leaf',
#   'Sample_Growth_Conditions': ''},
#  'Sample_Preparation': {'MALDI_Matrix': '2,5-dihydroxybenzoic acid (DHB)',
#   'Tissue_Modification': 'N/A',
#   'Sample_Stabilisation': 'Fresh frozen',
#   'MALDI_Matrix_Application': 'HTX M5 Sprayer',
#   'Solvent': '70% MeOH'},
#  'MS_Analysis': {'Polarity': 'Positive',
#   'Ionisation_Source': 'MALDI',
#   'Analyzer': '7 T FTICR',
#   'Detector_Resolving_Power': {'Resolving_Power': 110000, 'mz': 400},
#   'Pixel_Size': {'Xaxis': 30, 'Yaxis': 30}},
#  'Additional_Information': {'Supplementary': 'biopsy_18-162-2\n\n'}}

# %%
ds_df_tim = pd.DataFrame(
    {
        'ds_id': ds.id,
        'name': ds.name,
        'group': ds.group['shortName'] if ds.group else 'None',
        'submitter': ds.submitter['name'],
        # pylint: disable=protected-access
        'is_public': ds._info['isPublic'],
        'polarity': ds.metadata['MS_Analysis']['Polarity'],
        'organism': normalize_organism(ds.metadata['Sample_Information']['Organism']), #added
        'organism_part': normalize_organism_part(ds.metadata['Sample_Information']['Organism_Part']), #added
        'condition': normalize_condition(ds.metadata['Sample_Information']['Condition']), #added
        'source': normalize_source(ds.metadata['MS_Analysis']['Ionisation_Source']),
        'raw_source': ds.metadata['MS_Analysis']['Ionisation_Source'],
        'analyzer': normalize_analyzer(ds.metadata['MS_Analysis']['Analyzer']),
        'raw_analyzer': ds.metadata['MS_Analysis']['Analyzer'],
        'matrix': normalize_matrix(ds.metadata['Sample_Preparation']['MALDI_Matrix']),
        'raw_matrix': ds.metadata['Sample_Preparation']['MALDI_Matrix'],
        'solvent': normalize_solvent(ds.metadata['Sample_Preparation'].get('Solvent')),
        'raw_solvent': ds.metadata['Sample_Preparation'].get('Solvent'),
        'rp': normalize_resolving_power(ds.metadata['MS_Analysis']),
    }
    for ds in datasets_tim
    if ds
)

# %%
# The "20 labs" project shouldn't be included with EMBL as it gets unusual priority due to its
# diversity within the group
ext_datasets = [ds.id for ds in sm.datasets(project='62d1990a-a4ff-11eb-96db-abcc9848804b')]
ds_df_tim.loc[ds_df_tim.ds_id.isin(ext_datasets), 'group'] = 'None'

# %%
ds_df_tim.organism_part.value_counts().to_dict()
# Out:
# {'kidney': 1657,
#  'brain': 700,
#  'liver': 434,
#  'leaf': 396,
#  'whole organism': 307,
#  'breast': 249,
#  'root': 248,
#  'lymph node': 243,
#  'lung': 240,
#  'n/a': 234,
#  'ovary': 223,
#  'skin': 205,
#  'colon': 150,
#  'epididymis': 99,
#  'gill': 95,
#  'seed': 72,
#  'soft tissue with endometriosis': 68,
#  'stem': 64,
#  'colonies': 52,
#  'microbial colony': 48,
#  'none': 46,
#  'cells': 45,
#  'cervix': 38,
#  'eye': 34,
#  'buccal mucosa': 31,
#  'thyroid': 30,
#  'pancreas': 29,
#  'thorax exoskeleton': 28,
#  'root tip': 27,
#  'muscle': 26,
#  'spheroids': 25,
#  'bladder': 24,
#  'breast tumor': 24,
#  'endometrium': 23,
#  'berry': 22,
#  'wddm': 22,
#  'cervix | muscle': 22,
#  'psm': 20,
#  'carotid': 19,
#  'mammary gland': 19,
#  'agar growth': 18,
#  'prostate': 17,
#  'kideny': 17,
#  'spleen': 16,
#  'gratric cancer tissue': 16,
#  'fruit': 15,
#  'epithelial cells': 15,
#  'stomach': 14,
#  'testis': 14,
#  'small intestine': 14,
#  'mixed': 14,
#  'nodule': 13,
#  'root/soil': 13,
#  'jejunum': 12,
#  'ovary with endometriosis': 11,
#  'embryo': 10,
#  'artery': 10,
#  'left upper arm': 9,
#  'mln': 9,
#  'standards': 8,
#  'ear/skin': 8,
#  'prostate cancer cells': 8,
#  'retina': 7,
#  'omentum': 7,
#  'pancreatic cancer cell line - k8484': 7,
#  'necrosis': 7,
#  'heart': 6,
#  'peritoneum': 6,
#  'wafer': 6,
#  'neuron': 6,
#  'whole embryo': 6,
#  'tumour': 6,
#  'mush': 5,
#  'culture': 5,
#  'tissue section': 5,
#  'sciatic nerve': 5,
#  'bone': 5,
#  'hacat cells': 5,
#  'primary stem': 5,
#  'primary human epithelial keratinocytes neonatal (hekn cells) ': 4,
#  'amoeba': 4,
#  '3t3 fibroblast cells': 4,
#  'digestive system': 4,
#  'tumor': 4,
#  'dorsal root ganglion': 4,
#  'finger': 4,
#  'uterus': 3,
#  'blood cells': 3,
#  'spreadout': 3,
#  'plantlet': 3,
#  'spinal cord': 3,
#  'extract': 3,
#  'frond': 3,
#  'hela': 3,
#  'gut': 3,
#  'mesenchymal stromal cells': 2,
#  'rhizome': 2,
#  'glioblastoma': 2,
#  'artetry': 2,
#  'cerebellum': 2,
#  'gemm tumor': 2,
#  'somite': 2,
#  'tail': 2,
#  'skin tumor': 2,
#  'larynx': 2,
#  'mantle': 2,
#  'roots': 2,
#  'whole cells': 2,
#  'foot': 2,
#  'cross section': 2,
#  'flower': 1,
#  'mesenchymal cells': 1,
#  'bone marrow': 1,
#  'intestinal mucus': 1,
#  'semi mature barry': 1,
#  'osteosarcoma': 1,
#  'adrenal gland': 1,
#  'organ or organism part': 1,
#  'fallopian tube with endometriosis': 1,
#  'cell pellet': 1,
#  'tripartite': 1,
#  'tissue homogenate': 1,
#  'external tissues': 1,
#  'vascular tissues': 1,
#  'solid tumor': 1,
#  'gastrocnemius': 1,
#  'emt6 tumors': 1,
#  'xenograft tumors': 1,
#  'blood vessel': 1,
#  'macrophage': 1,
#  'cd4+ t cells': 1,
#  'tongue': 1,
#  'germinated seed': 1,
#  'homogenate': 1,
#  'mush ': 1,
#  'palm of hand': 1,
#  '3t3 fibroblast and primary human epithelial keratinocytes neonatal (hekn) cells ': 1,
#  'urinary bladder': 1,
#  'intestine': 1,
#  '3t3 fibroblast and hacat cells': 1,
#  'control': 1,
#  'macro': 1,
#  'root nodule': 1,
#  'colony': 1,
#  'leaves': 1,
#  'abdomen': 1,
#  't84 cells gut': 1,
#  'root, hyphae': 1,
#  'aorta': 1,
#  'sarcoma': 1,
#  'stomach mucus': 1}

# %%
ds_df_tim.head()
# Out:
#                   ds_id                                               name  \
# 0  2022-09-30_11h33m41s                        Mouse_brain_10um_NEDC_recal
# 1  2022-09-28_16h17m16s                             S1_NoLockMass_04012022
# 2  2022-09-27_16h46m14s  20220920_Image_3_D4NSD_HCCA_12L_10mgml_25mm_AC...
# 3  2022-09-24_00h46m58s                                         t1c1#1_pos
# 4  2022-09-24_00h44m30s                                         t3d5#2_pos
#
#               group             submitter  is_public  polarity organism  \
# 0  Spectroglyph LLC         Mikhail Belov       True  Negative    human
# 1  Spectroglyph LLC         Mikhail Belov       True  Negative    human
# 2              None  Maureen Feucherolles       True  Positive    human
# 3              PNNL      Dusan Velickovic       True  Positive   poplar
# 4              PNNL      Dusan Velickovic       True  Positive   poplar
#
#   organism_part condition source raw_source  analyzer raw_analyzer matrix  \
# 0         brain   control  MALDI      MALDI  Orbitrap     Orbitrap   NEDC
# 1        kidney   control  MALDI      MALDI  Orbitrap     Orbitrap    DAN
# 2          skin       n/a  MALDI   AP-MALDI  Orbitrap     Orbitrap   CHCA
# 3          leaf  wildtype  MALDI      MALDI     FTICR    7 T FTICR    DHB
# 4          leaf  wildtype  MALDI      MALDI     FTICR    7 T FTICR    DHB
#
#                                           raw_matrix solvent  \
# 0  n-(1-naphthyl)ethylenediamine dihydrochloride ...    MeOH
# 1                       1,5-diaminonaphthalene (DAN)    MeOH
# 2          alpha-cyano-4-hydroxycinnamic acid (CHCA)   Other
# 3                    2,5-dihydroxybenzoic acid (DHB)    MeOH
# 4                    2,5-dihydroxybenzoic acid (DHB)    MeOH
#
#                    raw_solvent        rp
# 0       70:30 methanol : water  120000.0
# 1  50 methanol 5% HCl in water  120000.0
# 2                         none  120000.0
# 3                     70% MeOH  220000.0
# 4                     70% MeOH  220000.0

# %%
# Build dictionaries with {ds_ids : # fdr annotations} for given fdr
d05, d10, d20, d50 = ([dict({}) for i in range(4)]) # initialize dicts
fdrs = [0.05, 0.1, 0.20, 0.50]
fdr_dicts = [d05, d10, d20, d50]

for d, fdr in zip(fdr_dicts, fdrs):
    for ds_id in fdr_dict.keys():
        try:
            d[ds_id] = fdr_dict[ds_id][fdr] # fdr_dict is a dictionary of dictionaries
        except KeyError:                    # Many datasets do not display all fdr values 
            d[ds_id] = float('NaN')
    
    # Map dictionaries to dataframe
    ds_df_tim['fdr{}'.format(str(int(fdr*100)))] = ds_df_tim['ds_id'].map(d)

# %%
ds_df_tim.head()
# Out:
#                   ds_id                                               name  \
# 0  2022-09-30_11h33m41s                        Mouse_brain_10um_NEDC_recal
# 1  2022-09-28_16h17m16s                             S1_NoLockMass_04012022
# 2  2022-09-27_16h46m14s  20220920_Image_3_D4NSD_HCCA_12L_10mgml_25mm_AC...
# 3  2022-09-24_00h46m58s                                         t1c1#1_pos
# 4  2022-09-24_00h44m30s                                         t3d5#2_pos
#
#               group             submitter  is_public  polarity organism  \
# 0  Spectroglyph LLC         Mikhail Belov       True  Negative    human
# 1  Spectroglyph LLC         Mikhail Belov       True  Negative    human
# 2              None  Maureen Feucherolles       True  Positive    human
# 3              PNNL      Dusan Velickovic       True  Positive   poplar
# 4              PNNL      Dusan Velickovic       True  Positive   poplar
#
#   organism_part condition source  ... raw_analyzer matrix  \
# 0         brain   control  MALDI  ...     Orbitrap   NEDC
# 1        kidney   control  MALDI  ...     Orbitrap    DAN
# 2          skin       n/a  MALDI  ...     Orbitrap   CHCA
# 3          leaf  wildtype  MALDI  ...    7 T FTICR    DHB
# 4          leaf  wildtype  MALDI  ...    7 T FTICR    DHB
#
#                                           raw_matrix solvent  \
# 0  n-(1-naphthyl)ethylenediamine dihydrochloride ...    MeOH
# 1                       1,5-diaminonaphthalene (DAN)    MeOH
# 2          alpha-cyano-4-hydroxycinnamic acid (CHCA)   Other
# 3                    2,5-dihydroxybenzoic acid (DHB)    MeOH
# 4                    2,5-dihydroxybenzoic acid (DHB)    MeOH
#
#                    raw_solvent        rp  fdr5  fdr10  fdr20   fdr50
# 0       70:30 methanol : water  120000.0   7.0    2.0   72.0  1242.0
# 1  50 methanol 5% HCl in water  120000.0  16.0   39.0  254.0  1042.0
# 2                         none  120000.0   1.0    NaN   20.0   206.0
# 3                     70% MeOH  220000.0   3.0    NaN    NaN   100.0
# 4                     70% MeOH  220000.0   2.0    NaN    2.0    96.0
#
# [5 rows x 22 columns]

# %%
# Find datasets that have very similar names (e.g. SlideA, SlideB, SlideC, etc) so that they can
# have their weights proportionately decreased. If someone uploads 20 very similar datasets, they
# should each only have 1/20th of a chance to be selected compared to a unique dataset.
ds_df_tim['batch_grouping'] = ds_df_tim.ds_id
last_grouping, last_name, last_submitter = '', '', ''
for row in (
    ds_df_tim.sort_values(
        'name',
        key=lambda s: s.str.replace(r'\d', '').str.replace('(sample|slide)[A-Z]', '\\1', case=True),
    )
    .sort_values('submitter', kind='stable')
    .itertuples()
):
    name = re.sub(r'\d', '', row.name)
    if row.submitter == last_submitter and distance(name, last_name) < 1:
        ds_df_tim.loc[row[0], 'batch_grouping'] = last_grouping
    else:
        last_grouping = row.ds_id
    last_name = name
    last_submitter = row.submitter
# Out:
# /tmp/ipykernel_4496/1580808964.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   key=lambda s: s.str.replace(r'\d', '').str.replace('(sample|slide)[A-Z]', '\\1', case=True),

# %%
# Exclude unwanted datasets
ds_mask = (
    # Primary criteria: Datasets should be public OR submitted by EMBL
    (ds_df_tim.is_public | (ds_df_tim.group == '♡EMBL♡'))
    # Exclude datasets that are obviously test submissions or re-uploads for some other
    # bioinformatic project
    & (ds_df_tim.name != 'Example file')
    & ~(ds_df_tim.name.str.startswith('Dataset '))
    & ~(ds_df_tim.name.str.endswith('_recal'))
    & ~(ds_df_tim.name.str.contains('test', case=False))
    # Exclude test datasets uploaded by METASPACE developers
    & ~ds_df_tim.submitter.isin(
        [
            'Lachlan Stuart',
            'Lachlan Nicholas Stuart',
            'Christopher Rath',
            'Andreas Eisenbarth',
            'Vitaly Kovalev',
            'Renat Nigmetzianov',
            'Vitaly Kovalev (admin)',
        ]
    )
    # Exclude datasets with a blank/deleted submitter
    & ~ds_df_tim.submitter.isna()
    # Exclude datasets with fewer than 10 HMDB annotations @ FDR 10%
    & (ds_df_tim.fdr10 > 10)
)

# %%
#%% Add derived columns
norm_ds_df = ds_df_tim.copy()

norm_ds_df['matrix_solvent'] = np.where(
    norm_ds_df.source == 'MALDI',
    norm_ds_df.matrix.replace({'Other': 'Other Matrix'}),
    norm_ds_df.solvent.replace({'Other': 'Other Solvent'}),
)
norm_ds_df['rp_range'] = np.select(
    [norm_ds_df.rp <= 80000, norm_ds_df.rp <= 200000], ['low', 'medium'], 'high'
)
norm_ds_df['batch_weight'] = (1 / norm_ds_df.batch_grouping.value_counts())[
    norm_ds_df.batch_grouping
].values

ds_df = norm_ds_df[ds_mask]

print(f'{len(ds_df)} / {len(norm_ds_df)}')
# Out:
# 3186 / 6844

# %%
#%%  Try to select a diverse but relatively representative sample of datasets
def get_stratified_sample(ds_df, count):
    weights = ds_df.batch_weight.copy()
    # For (col, count), take the top `count` values of `col` and compact the rest into an "Other"
    # category.  These are applied to the weights in order and the order has a big impact.
    # If a particular column isn't being proportionately represented in the results, try moving it
    # up or down in the list.
    ## The larger pop is, the more "diverse" the data becomes with respect to that column
    cols = [
        ('matrix_solvent', 7),
        ('polarity', 2),
        ('source', 2),
        ('analyzer', 2),
        ('rp_range', 3),
        ('submitter', 50),
        ('group', 20),
        ('polarity', 20),
        ('organism', 50),
        ('organism_part', 20),
        ('condition', 20)
    ]
    for col, pop in cols:
        group_weights = weights.groupby(ds_df[col]).sum() ** 0.5
        group_weights = group_weights.sort_values(ascending=False) # largest weight on top
        group_weights /= group_weights.sum() # normalizing
        other = group_weights.index.isin([*group_weights.index[pop:], 'Other']) 
        adjustment = pd.Series(
            np.where(other, 1 / max(group_weights[other].sum(), 0.001), 1 / group_weights),
            index=group_weights.index,
        )

        weights *= adjustment[ds_df[col].values].values

    # Slightly prefer newer datasets, as they're more representative of future datasets
    newness = np.maximum(ds_df.ds_id.str.slice(0, 4).astype(int) - 2013, 0)
    weights *= newness

    ds_df = ds_df.assign(weight=weights)
    return ds_df.sample(count, weights=ds_df.weight).sort_values(['group', 'ds_id'])

# %%
test_sample = get_stratified_sample(ds_df, 100)
test_sample.organism.value_counts()
# Out:
# human                                                16
# mouse                                                10
# acromyrmex octospinosus | pseudonocardia bacteria     6
# rat                                                   5
# acromyrmex echinatior | pseudonocardia bacteria       4
# maize                                                 4
# cultured cells                                        4
# pseudonocardia bacteria                               4
# n/a                                                   4
# camelina                                              3
# danio rerio (zebrafish)                               3
# brassica napus (rapeseed)                             2
# acromyrmex octospinosus                               2
# sus scrofa domesticus (pig)                           2
# arabidopsis                                           2
# sorghum                                               2
# fungal garden                                         2
# trichodesmium                                         2
# dog                                                   2
# gallus domesticus (chicken)                           2
# alaskan plant                                         2
# none                                                  1
# lucilia sericata                                      1
# candida albicans | escherichia coli                   1
# microbial                                             1
# candida albicans | pseudomonas aeruginosa             1
# trifolium repens                                      1
# strigeidida                                           1
# aconitum lycoctonum                                   1
# fittonia argyroneura                                  1
# leaf                                                  1
# macaca mulatta                                        1
# vitis vinifera                                        1
# macropus giganteus (kangaroo)                         1
# poplar                                                1
# marine culture                                        1
# leucoagaricus-escovopsis                              1
# piper                                                 1
# Name: organism, dtype: int64

# %%
random_sample = get_stratified_sample(ds_df, 500)
random_subsample = get_stratified_sample(random_sample, 100)
random_subsubsample = get_stratified_sample(random_subsample, 50)
random_sample['include_in_recal'] = random_sample.index.isin(random_subsample.index)
random_sample['include_in_pilot'] = random_sample.index.isin(random_subsubsample.index)
random_sample.to_csv('datasets/datasets.csv', index=False)
#%%  Make a link to view the datasets online
print('https://metaspace2020.eu/datasets?ds=' + ','.join(random_subsubsample.ds_id))
# Out:
# https://metaspace2020.eu/datasets?ds=2019-06-10_14h41m50s,2020-10-28_16h14m28s,2019-06-19_11h00m35s,2017-08-11_12h31m52s,2021-02-04_17h49m19s,2016-10-01_12h11m41s,2019-08-23_17h54m34s,2017-02-23_09h51m18s,2021-06-08_13h08m53s,2022-01-25_08h08m02s,2022-05-30_20h44m19s,2021-09-08_00h24m55s,2016-09-21_16h07m07s,2019-10-16_14h47m44s,2020-10-29_14h41m38s,2017-04-19_16h24m28s,2021-01-06_21h08m23s,2021-01-07_20h39m48s,2021-09-26_18h13m53s,2022-05-23_14h28m02s,2022-03-03_09h34m18s,2020-02-06_23h14m51s,2021-03-23_14h27m36s,2021-05-04_20h51m33s,2018-06-22_16h46m42s,2021-01-07_21h49m14s,2021-09-30_02h26m37s,2022-01-11_06h02m20s,2022-02-03_20h02m30s,2022-02-04_21h34m02s,2018-04-24_11h49m16s,2018-06-25_14h27m32s,2018-08-22_11h26m11s,2019-01-17_19h54m30s,2017-08-15_02h18m25s,2019-01-24_23h23m35s,2017-02-24_13h22m14s,2017-05-22_14h22m54s,2017-02-02_17h26m03s,2019-01-25_20h40m46s,2021-03-28_23h24m30s,2021-03-29_00h13m35s,2019-06-25_21h52m46s,2019-07-17_22h01m46s,2022-04-11_22h09m10s,2022-06-11_22h21m56s,2022-08-16_10h14m23s,2022-08-16_12h31m33s,2019-12-10_15h05m46s,2017-02-17_20h48m57s

# %%
#%% Plot distributions of datasets before/after sampling
cols = [
    ('group', 8),
    ('analyzer', 3),
    ('source', 3),
    ('polarity', 2),
    ('matrix_solvent', 8),
]

matplotlib.rc('font', size=8)
plt.close('all')
fig, axs = plt.subplots(4, len(cols), figsize=(12, 10))
for (col, pop), (ax1, ax2, ax3, ax4) in zip(cols, axs.T):
    avc = norm_ds_df[col].value_counts()
    vc = ds_df[col].value_counts()
    svc = random_sample[col].value_counts()
    pvc = random_sample[random_sample.include_in_pilot][col].value_counts()
    aligned = (
        pd.concat(
            [
                avc.to_frame('avc').T,
                vc.to_frame('vc').T,
                svc.to_frame('svc').T,
                pvc.to_frame('pvc').T,
            ]
        )
        .fillna(0)
        .T.sort_values('svc', ascending=False)
        .T
    )
    palette = dict(zip(aligned.columns, sns.color_palette(n_colors=len(aligned.columns))))
    colors = [palette[val] for val in aligned.columns]
    labels = [*aligned.columns[:pop]] + [None for i in range(pop, len(aligned.columns))]
    ax1.set_title(col.replace('matrix_solvent', 'matrix (MALDI) / solvent (non-MALDI)'))
    ax1.pie(aligned.loc['avc'], labels=labels, colors=colors, startangle=90, counterclock=False)
    ax2.pie(aligned.loc['vc'], labels=labels, colors=colors, startangle=90, counterclock=False)
    ax3.pie(aligned.loc['svc'], labels=labels, colors=colors, startangle=90, counterclock=False)
    ax4.pie(aligned.loc['pvc'], labels=labels, colors=colors, startangle=90, counterclock=False)

fig.suptitle('All-METASPACE Distribution', size=12)
axs[1, 2].set_title(
    'Available EMBL/Public datasets with >10 HMDB anns at <=10% FDR', y=1.1, size=12
)
axs[2, 2].set_title('Stratified sample (500 datasets)', y=1.1, size=12)
axs[3, 2].set_title('Stratified sample (50 datasets pilot)', y=1.1, size=12)
plt.tight_layout()
fig.savefig('datasets/sample.png')
plt.show()

# %%
random_sample
# Out:
#                      ds_id                                   name  \
# 1408  2016-09-21_16h06m49s            AstraZeneca//CT26_xenograft
# 4811  2016-09-21_16h06m53s                 AstraZeneca//Xenograft
# 1405  2016-10-28_10h26m38s                    xenograft CT-26 S10
# 1406  2016-12-09_10h16m23s                       DESI quan_Swales
# 4801  2019-05-31_11h02m14s                     slide a_pos_75-750
# ...                    ...                                    ...
# 3203  2017-11-16_18h49m46s            20171107_FB1_DHBpos_p70_s50
# 6659  2017-12-01_20h47m55s  20171201_CoCulture_DAN003_p60_s50_POS
# 3344  2018-03-23_11h59m35s           20170622_LR_FA21_DAN_p85_s40
# 6773  2018-03-23_12h02m30s            20170622_LR_U23_DAN_p85_s40
# 2172  2018-06-17_17h58m53s       160618_AR_MDCKII_DAN_Neg_p60_s50
#
#             group            submitter  is_public  polarity source raw_source  \
# 1408  AstraZeneca  Nicole Strittmatter       True  Negative    ESI       DESI
# 4811  AstraZeneca  Nicole Strittmatter       True  Positive    ESI       DESI
# 1405  AstraZeneca  Nicole Strittmatter       True  Negative    ESI       DESI
# 1406  AstraZeneca  Nicole Strittmatter       True  Positive    ESI       DESI
# 4801  AstraZeneca  Nicole Strittmatter       True  Positive    ESI       DESI
# ...           ...                  ...        ...       ...    ...        ...
# 3203       ♡EMBL♡          Luca Rappez       True  Positive  MALDI      MALDI
# 6659       ♡EMBL♡          Luca Rappez       True  Negative  MALDI      MALDI
# 3344       ♡EMBL♡          Luca Rappez       True  Negative  MALDI      MALDI
# 6773       ♡EMBL♡          Luca Rappez       True  Negative  MALDI      MALDI
# 2172       ♡EMBL♡   Angelos Rigopoulos       True  Negative  MALDI      MALDI
#
#       analyzer raw_analyzer  ...  fdr10   fdr20   fdr50        batch_grouping  \
# 1408  Orbitrap     Orbitrap  ...  537.0   811.0  2077.0  2016-09-21_16h06m49s
# 4811  Orbitrap     Orbitrap  ...  734.0   863.0   803.0  2016-09-21_16h06m53s
# 1405  Orbitrap     Orbitrap  ...  466.0  1162.0  2165.0  2016-10-28_10h26m38s
# 1406  Orbitrap     Orbitrap  ...  703.0  1302.0  3877.0  2016-12-09_10h16m23s
# 4801  Orbitrap     Orbitrap  ...   53.0   157.0  2523.0  2019-05-31_11h02m14s
# ...        ...          ...  ...    ...     ...     ...                   ...
# 3203  Orbitrap     Orbitrap  ...   39.0   158.0   682.0  2017-11-23_15h34m24s
# 6659  Orbitrap     Orbitrap  ...   32.0    50.0   184.0  2017-12-01_20h47m55s
# 3344  Orbitrap     Orbitrap  ...   49.0    88.0   536.0  2018-03-23_11h59m35s
# 6773  Orbitrap     Orbitrap  ...   11.0   100.0   472.0  2017-06-24_20h38m32s
# 2172  Orbitrap     Orbitrap  ...   35.0   210.0   455.0  2018-06-17_17h58m53s
#
#       matrix_solvent  rp_range  batch_weight         weight  include_in_recal  \
# 1408   Other Solvent    medium      1.000000  255582.014259             False
# 4811   Other Solvent    medium      1.000000  221931.026737             False
# 1405   Other Solvent    medium      1.000000  255582.014259             False
# 1406   Other Solvent    medium      1.000000  221931.026737             False
# 4801   Other Solvent       low      1.000000  772094.655887              True
# ...              ...       ...           ...            ...               ...
# 3203             DHB    medium      0.250000   25120.529343             False
# 6659             DAN    medium      1.000000  115718.033358             False
# 3344             DAN    medium      1.000000  144647.541698             False
# 6773             DAN    medium      0.166667   24107.923616             False
# 2172             DAN    medium      1.000000    3628.538465             False
#
#      include_in_pilot
# 1408            False
# 4811            False
# 1405            False
# 1406            False
# 4801            False
# ...               ...
# 3203            False
# 6659            False
# 3344            False
# 6773            False
# 2172            False
#
# [500 rows x 26 columns]

# %%
random_sample.weight
# Out:
# 1408    255582.014259
# 4811    221931.026737
# 1405    255582.014259
# 1406    221931.026737
# 4801    772094.655887
#             ...
# 3203     25120.529343
# 6659    115718.033358
# 3344    144647.541698
# 6773     24107.923616
# 2172      3628.538465
# Name: weight, Length: 500, dtype: float64

# %%
random_ids = random.sample(random_subsample.ds_id.to_list(), 5)

# %%
random_ids
# Out:
# ['2017-08-11_12h31m52s',
#  '2022-05-31_10h25m40s',
#  '2019-06-26_09h25m02s',
#  '2017-02-23_09h51m18s',
#  '2021-03-29_21h54m58s']

# %%
ds_rand = sm.dataset(id=random_ids[0])

# %%
ds_rand.metadata
# Out:
# {'Sample_Preparation': {'Sample_Stabilisation': 'Fresh frozen',
#   'MALDI_Matrix_Application': 'Spray robot',
#   'Tissue_Modification': 'None',
#   'MALDI_Matrix': '2,5-dihydroxybenzoic acid (DHB)'},
#  'Sample_Information': {'Organism_Part': 'Liver',
#   'Condition': 'Normal',
#   'Sample_Growth_Conditions': 'N/A',
#   'Organism': 'Homo sapiens (human)'},
#  'MS_Analysis': {'Analyzer': 'FTICR',
#   'Ionisation_Source': 'MALDI',
#   'Polarity': 'Positive',
#   'Detector_Resolving_Power': {'mz': 759, 'Resolving_Power': 121000}},
#  'Data_Type': 'Imaging MS',
#  'Additional_Information': {'Supplementary': ''}}
